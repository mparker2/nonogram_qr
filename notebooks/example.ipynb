# %% [markdown]
# # Create and solve QR code nonograms

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

from nonogram_qr import (nonogram_qr, solve_nonogram, 
                         draw_nonogram, draw_solver_progress)

## Default plotting params

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 2
style['ytick.major.size'] = 2
sns.set(font_scale=1, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)
sns.palplot(pal)
plt.show()

# %%
shape, rows, cols, mat = nonogram_qr('This is a test')
draw_nonogram(rows, cols, mat=mat)
plt.show()
# Out:
# e:\documents\nonogram_qr\nonogram_qr\solve.py:223: UserWarning: There are multiple ambiguous solutions
#   warn('There are multiple ambiguous solutions', UserWarning)

# %%
solved, _, imgs = solve_nonogram(rows, cols, shape, mat, return_iterations=True)
draw_solver_progress(
    imgs,
    imagemagick_path='C://Program Files//ImageMagick-7.0.8-Q16//magick.exe',
    imagemagick_extra_args=('convert', )
)
# Out:
# C:\Users\Matthew\Miniconda3\envs\jupyter_python3\lib\site-packages\matplotlib\animation.py:971: UserWarning: MovieWriter imagemagick unavailable
#   warnings.warn("MovieWriter %s unavailable" % writer)
